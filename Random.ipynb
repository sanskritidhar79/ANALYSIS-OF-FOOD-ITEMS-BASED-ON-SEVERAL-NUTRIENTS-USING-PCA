# %% [markdown]
# <a href="https://colab.research.google.com/github/sanskritidhar79/ANALYSIS-OF-FOOD-ITEMS-BASED-ON-SEVERAL-NUTRIENTS-USING-PCA/blob/master/Random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
for i in range(10):
  print(i*5)
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
