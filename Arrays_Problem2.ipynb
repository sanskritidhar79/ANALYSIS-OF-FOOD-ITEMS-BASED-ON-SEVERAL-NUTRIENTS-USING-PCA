# %% [markdown]
# <a href="https://colab.research.google.com/github/sanskritidhar79/ANALYSIS-OF-FOOD-ITEMS-BASED-ON-SEVERAL-NUTRIENTS-USING-PCA/blob/master/Arrays_Problem2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = input("Enter a number ")
num = int(num)

n = num
res = 0

while n>0:
  #taking last digit of the inital number
  temp = n%10

  # appending to resultant number
  res = res*10 + temp

  #diving intial number by 10 , to get the next number
  n = n//10

print("reversed number is ",res)
# Out:
# Enter a number 123
# reversed number is  321
